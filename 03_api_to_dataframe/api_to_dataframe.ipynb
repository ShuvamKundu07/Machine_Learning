# %%
import pandas as pd
import requests
import os
from dotenv import load_dotenv

from IPython.display import display

# %%
load_dotenv()

api_key = os.getenv("RAPIDAPI_KEY")
api_host = os.getenv("RAPIDAPI_HOST")

# %%
url = "https://imdb236.p.rapidapi.com/api/imdb/cast/nm0000190/titles"

headers = {
    "x-rapidapi-key": api_key,
    "x-rapidapi-host": api_host
}

response = requests.get(url, headers=headers)
print(response.status_code)
# Out:
# 200

# %%
df = pd.DataFrame(response.json())
df = df[['id', 'originalTitle', 'numVotes', 'averageRating', 'spokenLanguages']]

pd.set_option('display.expand_frame_repr', False)
print(df)
# Out:
#             id                               originalTitle  numVotes  averageRating spokenLanguages
# 0   tt41059410                 Bear Grylls Is Running Wild      66.0            6.3            [en]
# 1   tt21103218                                The Lost Bus   54585.0            6.8            [en]
# 2   tt27706593                   The Rivals of Amziah King     311.0            7.9            [en]
# 3   tt31937790   Superhuman Body: World of Medical Marvels      25.0            6.9            [en]
# 4   tt27590028                                  The Oscars    1634.0            6.7        [en, es]
# ..         ...                                         ...       ...            ...             ...
# 95   tt0141926                                       U-571   92202.0            6.6        [en, de]
# 96   tt0131369                                        EDtv   46812.0            6.1            [en]
# 97   tt0287789                       Waking in Mississippi      20.0            7.5            [en]
# 98   tt0773260  Bravo Profiles: The Entertainment Business      74.0            6.4            [en]
# 99   tt0120769                             The Newton Boys   13229.0            6.1            [en]
#
# [100 rows x 5 columns]

# %%
df.to_csv('movies.csv')
