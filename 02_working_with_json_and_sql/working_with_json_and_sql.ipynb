# %% [markdown]
# ## Working with JSON

# %%
import pandas as pd

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
# pd.read_json('https://api.demo')    "dataframe can be made by the url also"

# %% [markdown]
# ## Working with SQL

# %%
# !pip3 install mysql.connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 10.4 MB/s  0:00:01 eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp314-cp314-macosx_10_15_universal2.whl size=248049 sha256=5390aaf872dad20de1020d27f24fe76dcc13b1c94ebd41839e5bfa67a3340a5b
#   Stored in directory: /Users/shuvamkundu/Library/Caches/pip/wheels/a2/5a/60/e03682d488f501428666827b000cfa0da00163afcd74ce2c14
# Successfully built mysql.connector
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import mysql.connector

# %%
connection = mysql.connector.connect(host="localhost", user="root", password="", database="world")

pd.read_sql_query("SELECT * FROM city", connection)
# Out:
# /var/folders/2z/nd6k38px5v762w76tqgx8fsm0000gn/T/ipykernel_72918/3618087865.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city", connection)
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# ...

# %%
pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'IND' ", connection) #by writing queries we can filter on the dataset
# Out:
# /var/folders/2z/nd6k38px5v762w76tqgx8fsm0000gn/T/ipykernel_72918/2919887209.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'IND' ", connection) #by writing queries we can filter on the dataset
#        ID                Name CountryCode        District  Population
# 0    1024     Mumbai (Bombay)         IND     Maharashtra    10500000
# 1    1025               Delhi         IND           Delhi     7206704
# 2    1026  Calcutta [Kolkata]         IND    West Bengali     4399819
# 3    1027    Chennai (Madras)         IND      Tamil Nadu     3841396
# 4    1028           Hyderabad         IND  Andhra Pradesh     2964638
# ..    ...                 ...         ...             ...         ...
# 336  1360        Ambala Sadar         IND         Haryana       90712
# ...

# %%
pd.read_sql_query("SELECT * FROM country WHERE 	LifeExpectancy > 50", connection)
# Out:
# /var/folders/2z/nd6k38px5v762w76tqgx8fsm0000gn/T/ipykernel_72918/4202908725.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM country WHERE 	LifeExpectancy > 50", connection)
#     Code                  Name      Continent           Region  SurfaceArea  \
# 0    ABW                 Aruba  North America        Caribbean        193.0
# 1    AIA              Anguilla  North America        Caribbean         96.0
# 2    ALB               Albania         Europe  Southern Europe      28748.0
# 3    AND               Andorra         Europe  Southern Europe        468.0
# 4    ANT  Netherlands Antilles  North America        Caribbean        800.0
# ..   ...                   ...            ...              ...          ...
# 189  VUT               Vanuatu        Oceania        Melanesia      12189.0
# ...
